# %% [markdown]
# # Task 1 and Task 2 Performed in all Tasks

# %% [markdown]
# # Task 3

# %%
# %run task_3.py --help
# Out:
# Usage: task_3.py [OPTIONS] CREATE INPUT_FILE_PATH OUTPUT_FILE_PATH
#
#   click function to perform CLI task in generating a network graph, param
#   create: label of the CLI command, param input_file_path : name of the PPI
#   file, param output_file_path : name of the output file, return : network
#   graph
#
# Options:
#   --help  Show this message and exit.

# %%
# %run task_3.py create ppis.cab   task_3_output.jpg
# Out:
# Usage: task_3.py [OPTIONS] CREATE INPUT_FILE_PATH OUTPUT_FILE_PATH
# Try "task_3.py --help" for help.
#
# Error: Invalid value for "INPUT_FILE_PATH": Path "ppis.cab" does not exist.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
# %run task_3.py create ppis.csv   task_3_output.txt
# Out:
# This '.docx' and '.txt' format is not acceptable, prefer using .pdf , .png, .jpeg

# %%
# %run task_3.py create ppis.csv   task_3_output.pdf

# %% [markdown]
# # Task 4

# %%
# %run task_4.py --help
# Out:
# Usage: task_4.py [OPTIONS] CREATE OUTPUT_FILE_PATH
#
#   overall click function to generate network graph, param create: label of
#   the cli command, param ppi: name of the ppi file, param nodes : name of
#   the node file, param edges : name of the edge file, param output_file_path
#   : name of the output file to be generated, return graph
#
# Options:
#   -p, --ppi PATH    Name of the Protein-Protein Interaction File
#   -n, --nodes PATH  Name of the Node File
#   -e, --edges PATH  Name of the Edge File
#   --help            Show this message and exit.

# %%
# %run task_4.py create --ppi ppis.csv task_4_output.pdf

# %%
# %run task_4.py create --ppi ppis.csv task_4_output.txt
# Out:
# This '.docx' and '.txt' format is not acceptable, prefer using .pdf , .png, .jpeg

# %%
# %run task_4.py create --nodes  node_list.tsg --edges edge_output.tsv task_4_output.pdf
# Out:
# Usage: task_4.py [OPTIONS] CREATE OUTPUT_FILE_PATH
# Try "task_4.py --help" for help.
#
# Error: Invalid value for "-n" / "--nodes": Path "node_list.tsg" does not exist.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
# %run task_4.py create --nodes  node_list.tsv --edges edge_output.tsv task_4_output.pdf

# %% [markdown]
# # Task 5 - Shown in Task 3, 4

# %% [markdown]
# # Task 6

# %%
# %run task_6.py --help
# Out:
# Usage: task_6.py [OPTIONS] PATH
#
#   click function to highlight the shortest path the source and target nodes,
#   param source: starting node, param target: ending node param ppi: PPI file
#   param nodes : node file param edges: edge file param output: output file
#
# Options:
#   --source TEXT     Name of the Source Node [must]
#   --target TEXT     Name of the Target Node [must]
#   -p, --ppi PATH    Name of the Protein-Protein Interaction File [optional]
#   -n, --nodes PATH  Name of the Node File [optional]
#   -e, --edges PATH  Name of the Edge File [optional]
#   --output TEXT     Name of the Output File
#   --help            Show this message and exit.

# %%
# %run task_6.py  path --source "RPA1" --target "LSM3" --nodes node_output.tsv --edges edge_list1.tsv --output output.pdf
# Out:
# Usage: task_6.py [OPTIONS] PATH
# Try "task_6.py --help" for help.
#
# Error: Invalid value for "-e" / "--edges": Path "edge_list1.tsv" does not exist.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
# %run task_6.py  path  --source "PRKAR1A"  --target "CUL3" --ppi ppis.csv --output task_6_output.pdf
# Out:
# There are 2 paths available between the given nodes between PRKAR1A and CUL3
# [['PRKAR1A', 'MTOR', 'GNB1', 'PIK3R1', 'BRCA1', 'BARD1', 'PGAM5', 'PRKN', 'PSMD1', 'BLM', 'RPA1', 'PAN2', 'SRSF3', 'CUL3'], ['PRKAR1A', 'MTOR', 'GNB1', 'PIK3R1', 'BRCA1', 'SMARCB1', 'PPP1CA', 'HDAC5', 'PSMD1', 'BLM', 'RPA1', 'PAN2', 'SRSF3', 'CUL3']]
# The new custom output filename is task_6_output_shortest_path_PRKAR1A_CUL3.pdf

# %%
# %run task_6.py  path  --source "CREBBP"  --target "TRA2B" --ppi ppis.csv --output task_6_output.pdf
# Out:
# There are 2 paths available between the given nodes between CREBBP and TRA2B
# [['CREBBP', 'CREB1', 'EP300', 'REL', 'BTRC', 'TP63', 'SUMO1', 'MTOR', 'GNB1', 'PIK3R1', 'BRCA1', 'BARD1', 'PGAM5', 'PRKN', 'PSMD1', 'BLM', 'RPA1', 'PAN2', 'SRSF3', 'S100A9', 'TRA2B'], ['CREBBP', 'CREB1', 'EP300', 'REL', 'BTRC', 'TP63', 'SUMO1', 'MTOR', 'GNB1', 'PIK3R1', 'BRCA1', 'SMARCB1', 'PPP1CA', 'HDAC5', 'PSMD1', 'BLM', 'RPA1', 'PAN2', 'SRSF3', 'S100A9', 'TRA2B']]
# The new custom output filename is task_6_output_shortest_path_CREBBP_TRA2B.pdf

# %%
# %run task_6.py  path --source "LMO7" --target "PPP1CB" --nodes node_output.tsv --edges edge_list_task_6.tsv --output output.pdf
# Out:
# There are 1 paths available between the given nodes between LMO7 and PPP1CB
# [['LMO7', 'PPP1CB']]
# The new custom output filename is output_shortest_path_LMO7_PPP1CB.pdf

# %%
# %run task_6.py  path --source "PRKAR1A" --target "CUL3" --nodes node_output.tsv --edges edge_list_task_6.tsv --output output.pdf
# Out:
# There are 2 paths available between the given nodes between PRKAR1A and CUL3
# [['PRKAR1A', 'MTOR', 'GNB1', 'PIK3R1', 'BRCA1', 'BARD1', 'PGAM5', 'PRKN', 'PSMD1', 'BLM', 'RPA1', 'PAN2', 'SRSF3', 'CUL3'], ['PRKAR1A', 'MTOR', 'GNB1', 'PIK3R1', 'BRCA1', 'SMARCB1', 'PPP1CA', 'HDAC5', 'PSMD1', 'BLM', 'RPA1', 'PAN2', 'SRSF3', 'CUL3']]
# The new custom output filename is output_shortest_path_PRKAR1A_CUL3.pdf
